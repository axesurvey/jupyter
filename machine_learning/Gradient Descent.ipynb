# %% [markdown]
# # Machine learning algorithm study
# ## Gradient Descent -- 梯度下降算法 实现以及原理

# %% [markdown]
# 公示的推导方法：
#
# https://www.coursera.org/learn/machine-learning/supplement/U90DX/gradient-descent-for-linear-regression
# http://202.207.240.30/DaXueMath/links/network%20study/NetStudy/ch3/3-2.htm
#
# 主要看一下求导数的定理。  这里用到的是定理3.

# %%
from IPython.display import display, Image
display(Image('http://www.google.fr/images/srpr/logo3w.png'))

# %% [markdown]
# $$\int_0^{+\infty} x^2 dx$$

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy
x = numpy.linspace(0, 1, 100)**1.5
plt.hist(x);

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy
x = [(1, 0., 3), (1, 1., 3), (1, 2., 3), (1, 3., 2), (1, 4., 4)]

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.gca(projection='3d')
x = np.linspace(-5, 5, 200)
y = x
x,y = np.meshgrid(x,y)
z = 97.719251 + (-13.224330)*x + 1.342051*y

#ax.scatter(x,y,z, color='r', marker='o')

#theta0 : 97.719251, theta1 : -13.224330, theta2 : 1.342051,
surf = ax.plot_surface(x, y, z)

#ax.set_zlim(0, 0.2)

#ax.zaxis.set_major_locator(plt.LinearLocator(10))
#ax.zaxis.set_major_formatter(plt.FormatStrFormatter('%.02f'))

#fig.colorbar(surf, shrink=0.5, aspect=7, cmap=plt.cm.coolwarm)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

X = []
